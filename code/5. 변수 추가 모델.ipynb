# %% [markdown]
# # Data Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/drive/Shareddrives/도터디/캡스톤 디자인/data/fin_data.csv')
del dataset['Unnamed: 0']

# %%
len(dataset['jpg_count'])
# Out:
# 1941

# %% [markdown]
# # Train Test Set

# %%
X = dataset[['image_count', 'jpg_count', 'video_count', 'price', 'price_goal',
       'facebook_supporter_count', 'new_info_count', 'supporter_count',
       'like_count', 'newness', 'price_avg', 'product_count',
       'maker_respon_time', 'funding_duration', 'title_length',
       'summary_length', 'content_length', 'encore', 'image_percent',
       'jpg_percent', 'video_percent', 'price_power', 'market_saturation',
       'topic1','topic2', 'topic3']]
y = dataset['success']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# # 정규화

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # **다중공선성 및 상관계수**

# %%
from statsmodels.formula.api import ols

# %%
model = ols('success ~ image_count + jpg_count + video_count + price + price_goal + facebook_supporter_count + new_info_count + supporter_count + like_count + newness + price_avg + product_count + maker_respon_time + funding_duration + title_length + summary_length + content_length + encore + image_percent + jpg_percent + video_percent + price_power + market_saturation + topic1 + topic2 + topic3', dataset)

# %%
res = model.fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                success   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.312
# Method:                 Least Squares   F-statistic:                     34.87
# Date:                Wed, 26 Oct 2022   Prob (F-statistic):          1.16e-140
# Time:                        00:17:52   Log-Likelihood:                -128.50
# No. Observations:                1941   AIC:                             311.0
# Df Residuals:                    1914   BIC:                             461.4
# Df Model:                          26
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.0524      0.073     -0.719      0.472      -0.195       0.091
# image_count                 -0.0003      0.000     -0.992      0.321      -0.001       0.000
# jpg_count                    0.0032      0.001      5.455      0.000       0.002       0.004
# video_count                 -0.0171      0.006     -2.747      0.006      -0.029      -0.005
# price                     2.116e-08   2.54e-08      0.832      0.405   -2.87e-08     7.1e-08
# price_goal               -3.344e-09   7.45e-10     -4.487      0.000   -4.81e-09   -1.88e-09
# facebook_supporter_count     0.0016      0.001      2.253      0.024       0.000       0.003
# new_info_count            5.272e-05   9.16e-06      5.753      0.000    3.47e-05    7.07e-05
# supporter_count           5.013e-05   1.29e-05      3.893      0.000    2.49e-05    7.54e-05
# like_count                   0.0002   2.08e-05      9.267      0.000       0.000       0.000
# newness                      0.0126      0.014      0.875      0.382      -0.016       0.041
# price_avg                 3.126e-07    1.2e-07      2.610      0.009    7.77e-08    5.47e-07
# product_count             8.471e-05      0.000      0.629      0.530      -0.000       0.000
# maker_respon_time         1.353e-05   1.61e-05      0.842      0.400    -1.8e-05     4.5e-05
# funding_duration            -0.0009      0.001     -1.284      0.199      -0.002       0.000
# title_length                 0.0119      0.004      3.335      0.001       0.005       0.019
# summary_length              -0.0004      0.001     -0.340      0.734      -0.003       0.002
# content_length           -3.635e-05   1.11e-05     -3.261      0.001   -5.82e-05   -1.45e-05
# encore                       0.0322      0.016      2.062      0.039       0.002       0.063
# image_percent                0.0062      0.012      0.500      0.617      -0.018       0.030
# jpg_percent                  0.0455      0.051      0.886      0.376      -0.055       0.146
# video_percent               -0.2510      0.293     -0.858      0.391      -0.825       0.323
# price_power                 -0.0336      0.007     -4.554      0.000      -0.048      -0.019
# market_saturation            0.0012      0.020      0.061      0.951      -0.037       0.040
# topic1                      -0.0175      0.040     -0.436      0.663      -0.096       0.061
# topic2                       0.0074      0.042      0.178      0.859      -0.074       0.089
# topic3                      -0.0403      0.046     -0.871      0.384      -0.131       0.050
# ==============================================================================
# Omnibus:                      574.393   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1983.798
# Skew:                           1.446   Prob(JB):                         0.00
# Kurtosis:                       7.020   Cond. No.                     4.26e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.26e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# 다중공선성 확인

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
model.exog_names
# Out:
# ['Intercept',
#  'image_count',
#  'jpg_count',
#  'video_count',
#  'price',
#  'price_goal',
#  'facebook_supporter_count',
#  'new_info_count',
#  'supporter_count',
#  'like_count',
#  'newness',
#  'price_avg',
#  'product_count',
#  'maker_respon_time',
#  'funding_duration',
#  'title_length',
#  'summary_length',
#  'content_length',
#  'encore',
#  'image_percent',
#  'jpg_percent',
#  'video_percent',
#  'price_power',
#  'market_saturation',
#  'topic1',
#  'topic2',
#  'topic3']

# %%
pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
             for i, column in enumerate(model.exog_names)
             if column != 'Intercept')  # 절편의 VIF는 구하지 않는다.
# Out:
#                           컬럼       VIF
# 0                image_count  1.492532
# 1                  jpg_count  1.320040
# 2                video_count  1.085461
# 3                      price  1.413845
# 4                 price_goal  1.069009
# 5   facebook_supporter_count  1.027665
# 6             new_info_count  1.289104
# 7            supporter_count  3.473317
# 8                 like_count  3.845115
# 9                    newness  1.066507
# 10                 price_avg  1.357189
# 11             product_count  2.258470
# 12         maker_respon_time  1.044826
# 13          funding_duration  1.168390
# 14              title_length  1.067288
# 15            summary_length  1.065886
# 16            content_length  1.468818
# 17                    encore  1.062652
# 18             image_percent  3.891522
# 19               jpg_percent  3.573696
# 20             video_percent  1.249911
# 21               price_power  1.326819
# 22         market_saturation  2.242146
# 23                    topic1  6.299363
# 24                    topic2  5.279665
# 25                    topic3  3.728763

# %%
#pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
#             for i, column in enumerate(model.exog_names)
#             if column != 'Intercept').to_csv('/content/drive/Shareddrives/도터디/캡스톤 디자인/data/vif.csv')

# %%
feature = ['image_count', 'jpg_count', 'video_count', 'price', 'price_goal',
       'facebook_supporter_count', 'new_info_count', 'supporter_count',
       'like_count', 'newness', 'price_avg', 'product_count',
       'maker_respon_time', 'funding_duration', 'title_length',
       'summary_length', 'content_length', 'encore', 'image_percent',
       'jpg_percent', 'video_percent', 'price_power', 'market_saturation',
       'topic1', 'topic2', 'topic3']

# %%
def model_coef(model):
  model_df = pd.DataFrame()
  coef = []
  for i in model:
    for j in i:
       coef.append(j)

  model_df['X'] = feature
  model_df['coef'] = coef

  return model_df.sort_values('coef',ascending =False)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
LI = LinearRegression()
LI.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('train_set : ',LI.score(X_train, y_train))
print('test_set : ',LI.score(X_test, y_test))
# Out:
# train_set :  0.33256471312370695
# test_set :  0.24846121144288036

# %%
LI_df = pd.DataFrame()
linearcoef = []
for i in LI.coef_:
  linearcoef.append(i)
LI_df['X'] = feature
LI_df['coef'] = linearcoef
LI_df.sort_values('coef',ascending =False)
# Out:
#                            X      coef
# 7            supporter_count  0.083406
# 8                 like_count  0.070471
# 1                  jpg_count  0.039385
# 6             new_info_count  0.030365
# 14              title_length  0.023737
# 10                 price_avg  0.019229
# 5   facebook_supporter_count  0.013601
# 19               jpg_percent  0.011648
# 17                    encore  0.011264
# 3                      price  0.009761
# 11             product_count  0.007130
# 9                    newness  0.001293
# 12         maker_respon_time  0.001162
# 13          funding_duration -0.001174
# 22         market_saturation -0.001264
# 20             video_percent -0.002052
# 15            summary_length -0.002198
# 24                    topic2 -0.002885
# 0                image_count -0.006423
# 18             image_percent -0.007122
# 23                    topic1 -0.009682
# 25                    topic3 -0.010581
# 2                video_count -0.014040
# 4                 price_goal -0.024787
# 16            content_length -0.025523
# 21               price_power -0.032741

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print('train_set : ',LR.score(X_train, y_train))
print('test_set : ',LR.score(X_test, y_test))
# Out:
# train_set :  0.940893470790378
# test_set :  0.9197530864197531

# %%
import statsmodels.api as sm

logis = sm.Logit.from_formula('success ~ image_count + jpg_count + video_count + price + price_goal + facebook_supporter_count + new_info_count + supporter_count + like_count + newness + price_avg + product_count + maker_respon_time + funding_duration + title_length + summary_length + content_length + encore + image_percent + jpg_percent + video_percent + price_power + market_saturation + topic1 + topic2 + topic3', dataset).fit()

logis.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.137824
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                success   No. Observations:                 1941
# Model:                          Logit   Df Residuals:                     1914
# Method:                           MLE   Df Model:                           26
# Date:                Wed, 26 Oct 2022   Pseudo R-squ.:                  0.6041
# Time:                        00:17:54   Log-Likelihood:                -267.52
# converged:                       True   LL-Null:                       -675.70
# Covariance Type:            nonrobust   LLR p-value:                2.468e-155
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -6.1860      1.713     -3.611      0.000      -9.544      -2.828
# image_count                  0.0065      0.006      1.061      0.289      -0.006       0.019
# jpg_count                    0.0419      0.010      4.357      0.000       0.023       0.061
# video_count                 -0.2057      0.131     -1.571      0.116      -0.462       0.051
# price                      2.43e-06    5.5e-07      4.418      0.000    1.35e-06    3.51e-06
# price_goal               -1.945e-06   1.93e-07    -10.087      0.000   -2.32e-06   -1.57e-06
# facebook_supporter_count     0.0060      0.006      0.953      0.340      -0.006       0.018
# new_info_count               0.0005      0.000      3.605      0.000       0.000       0.001
# supporter_count              0.0013      0.000      4.292      0.000       0.001       0.002
# like_count                   0.0037      0.001      7.278      0.000       0.003       0.005
# newness                     -0.3099      0.282     -1.098      0.272      -0.863       0.243
# price_avg                 1.249e-05   2.32e-06      5.379      0.000    7.94e-06     1.7e-05
# product_count                0.0007      0.003      0.214      0.831      -0.006       0.007
# maker_respon_time            0.0008      0.002      0.505      0.614      -0.002       0.004
# funding_duration            -0.0133      0.016     -0.812      0.417      -0.045       0.019
# title_length                 0.1880      0.075      2.524      0.012       0.042       0.334
# summary_length               0.0254      0.028      0.901      0.368      -0.030       0.081
# content_length              -0.0002      0.000     -0.931      0.352      -0.001       0.000
# encore                       0.7239      0.281      2.577      0.010       0.173       1.274
# image_percent                0.0902      0.183      0.492      0.623      -0.269       0.450
# jpg_percent                 -0.4565      0.818     -0.558      0.577      -2.059       1.146
# video_percent               -2.4980     29.261     -0.085      0.932     -59.848      54.852
# price_power                 -1.1097      0.183     -6.067      0.000      -1.468      -0.751
# market_saturation            0.2922      0.420      0.695      0.487      -0.532       1.116
# topic1                       0.1215      0.838      0.145      0.885      -1.521       1.764
# topic2                       0.5464      0.864      0.633      0.527      -1.146       2.239
# topic3                      -0.1050      0.956     -0.110      0.913      -1.978       1.768
# ============================================================================================
#
# Possibly complete quasi-separation: A fraction 0.16 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %% [markdown]
# Logistic Regression 상관계수

# %%
model_coef(LR.coef_)
# Out:
#                            X      coef
# 8                 like_count  1.265697
# 7            supporter_count  0.887143
# 10                 price_avg  0.494841
# 1                  jpg_count  0.425863
# 6             new_info_count  0.409562
# 14              title_length  0.405624
# 3                      price  0.280336
# 17                    encore  0.213090
# 0                image_count  0.096956
# 11             product_count  0.088282
# 19               jpg_percent  0.082545
# 5   facebook_supporter_count  0.075647
# 24                    topic2  0.054997
# 22         market_saturation  0.035443
# 15            summary_length  0.024667
# 9                    newness -0.043551
# 25                    topic3 -0.065917
# 20             video_percent -0.066545
# 13          funding_duration -0.105821
# 23                    topic1 -0.107579
# 2                video_count -0.177318
# 18             image_percent -0.226135
# 16            content_length -0.263383
# 12         maker_respon_time -0.543490
# 21               price_power -0.874137
# 4                 price_goal -5.842937

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print('train_set : ',DT.score(X_train, y_train))
print('test_set : ',DT.score(X_test, y_test))
# Out:
# train_set :  1.0
# test_set :  0.8806584362139918

# %% [markdown]
# DecisionTree 상관계수

# %% [markdown]
# # SVM

# %%
import sklearn.svm as svm
